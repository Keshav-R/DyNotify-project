# %%
from selectorlib import Extractor
import requests 
import json 




Ext = Extractor.from_yaml_file('search_results.yml')

def scrape(url):  

    heads = {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

   
    print("Downloading %s"%url)
    req = requests.get(url, headers=heads)
    
    
    if req.status_code > 500:
        if "To discuss automated access to Amazon data please contact" in r.text:
            print("Page %s was blocked by Amazon. Please try using better proxies\n"%url)
        else:
            print("Page %s must have been blocked by Amazon as the status code was %d"%(url,r.status_code))
        return None
    
    
    return Ext.extract(req.text)

inputurl = input("Enter Item:")
url= 'https://www.amazon.in/s?k=' + inputurl + '/&ref=nb_sb_noss_2'
with open('search_results.jsonl','w') as outfile:
    
        data = scrape(url) 
        if data:
            for product in data['products']:
                product['search_url'] = inputurl
                print("Saving Product: %s"%product['title'])
                json.dump(product,outfile)
                outfile.write("\n")
print("\n\n\nDumped in search_results.jsonl")
# Out:
# Enter Url:womens sunglasses
# ['womens', 'sunglasses']
# Downloading https://www.amazon.in/s?k=womens sunglasses/&ref=nb_sb_noss_2
# Saving Product: Polarized Butterfly Women's Sunglasses - (P8430 581 58LA|58|Brown Color)
# Saving Product: UV Protected Oval Women's Sunglasses (224, 58 mm, Black Lens)
# Saving Product: UV Protected Oval Women's Sunglasses (58 mm, Brown)
# Saving Product: Anti-Reflective Cat Eye Women's Sunglasses - (NA74|48|White Color Lens)
# Saving Product: Small Classic Square Polygon Round Men Women Sunglasses
# Saving Product: Gandhi Round Shape Retro UV Protection Multicolour Men's and Women's Sunglasses Shades (Combo of 6)
# Saving Product: Gradient Goggle Women's Sunglasses - (C085BK1F|54|Black Color)
# Saving Product: Black Transparent UV Protection Rectangular Sunglasses Frame For Men & Women (Clear)
# Saving Product: Aviator UV 400 Protection Green Glass Golden Frame Sunglasses for Men and Women with Attractive Case
# Saving Product: Nightdrive Driving Easy Day and Night HD Vision Anti-Glare Polarized Black Women's Sunglasses (Yellow)
# Saving Product: Metal Body Sunglasses Kabir Singh Sunglasses for Men and Women
# Saving Product: Wayfarer Combo with UV Protection Men and Women Sunglasses (55, Green and Black)
# Saving Product: WAQIF Day & Night Unisex HD Vision Goggles Sunglasses Men/Women Driving Glasses Sun Glasses (Yellow-Black) -Combo Pack Set of 2
# Saving Product: Yellow Lens Black Frame Night Vision Driving Sunglasses for Men and Women
# Saving Product: Tony Stark Iron Man Mirror Black Metal Men's and Women's Sunglasses (H1GKR-T012, Transparent)
# Saving Product: UV Protected Clear Black Round Frame Metal and Polycarbonate Men's and Women's Sunglass (Clear-!!!)
# Saving Product: Elastic Silicone Eyeglasses Strap Holder Waterproof Glasses Retainer, Sports Sunglasses Chain 3 Pack Women Men Kids
# Saving Product: Women's Cotton Hipster (Pack of 3) (Colors may vary)(color may vary)
# Saving Product: Iron Man Tony Stark Avengers Infinity War Metallic Stylish Sunglasses for Men and Boys (Silver-SkyBlue) -Large Size
# Saving Product: UV Protected Oval Multicolour Women's Sunglasses (158| 58 mm| Black Lens)
# Saving Product: UV Protected Oval Red Women's Sunglasses (145| 58 mm| Black Lens)
# Saving Product: UV Protected Oval Women's Sunglasses (58 mm, Black Lens)
# Saving Product: Women's UV Protected Oval Sunglasses/Eyewear (Lens-Multicolour)
# Saving Product: Anti-Reflective Cat Eye Women's Sunglasses - (NA69|50|White Color Lens)
