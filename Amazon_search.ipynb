# %%
from selectorlib import Extractor
import requests 
import json 



Ext = Extractor.from_yaml_file('search_results.yml')

def scrape(url):  

    heads = {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

   
    print("Downloading %s"%url)
    req = requests.get(url, headers=heads)
    
    
    if req.status_code > 500:
        if "To discuss automated access to Amazon data please contact" in r.text:
            print("Page %s was blocked by Amazon. Please try using better proxies\n"%url)
        else:
            print("Page %s must have been blocked by Amazon as the status code was %d"%(url,r.status_code))
        return None
    
    
    return Ext.extract(req.text)

inputurl = input("Enter Url:")

with open('search_results.jsonl','w') as outfile:
    
        data = scrape(inputurl) 
        if data:
            for product in data['products']:
                product['search_url'] = inputurl
                print("Saving Product: %s"%product['title'])
                json.dump(product,outfile)
                outfile.write("\n")
print("\n\n\nDumped in search_results.jsonl")
# Out:
# Enter Url:https://www.amazon.in/s?k=sunglass&ref=nb_sb_noss_2
# ...
# Saving Product: Polarized Aviator Black Sunglasses with TAC Material Sunglasses For Men Latest and Sunglasses For men Stylish Wayfarer Sunglasses for Medium size धूप का चश्मा
# Saving Product: LATEST BLACK TRENDY FAMOUS BADSHAH | JAS MANAK | SAHIL KHAN SQUARE UNISEX STYLISH SUNGLASSES
# Saving Product: UV Protected Polarized Sunglasses Metal Body Round Sunglasses For Men And Women(92235)
# Saving Product: Square Metal Body Kabir Singh Sunglass for Men & Boy
# Saving Product: Branded Metal Body Square Inspired from Kabir Singh Sunglass for Men and Boys
# Saving Product: Combo Pack of 5 Aviator Unisex Sunglasses With Pouch (Multicolor | Free Size | UV Protection)
# Saving Product: UV protected Square Men's Sunglasses (P357BK1|41 millimeters|Smoke (Grey/Black))
# Saving Product: Golden-Black UV Protection Octagonal Sunglasses/Frame For Men & Women
# ...
